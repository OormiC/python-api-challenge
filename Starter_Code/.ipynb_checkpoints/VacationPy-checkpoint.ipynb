# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0        port alfred -33.5906   26.8910     14.54        81
# 1        1        surat thani   9.1667   99.2500     31.23        87
# 2        2           karratha -20.7377  116.8463     36.61        20
# 3        3  port-aux-francais -49.3500   70.2167      1.88        75
# 4        4         bredasdorp -34.5322   20.0403     15.49        73
#
#    Cloudiness  Wind Speed Country        Date
# 0          57        1.79      ZA  1698036258
# 1          20        6.71      TH  1698036259
# 2          42        4.97      AU  1698036259
# 3          90       12.71      TF  1698036260
# 4         100        2.33      ZA  1698036260

# %%
pip install geoviews
# Out:
# Requirement already satisfied: geoviews in c:\users\oormi\anaconda3\lib\site-packages (1.10.1)
# Requirement already satisfied: bokeh<3.3.0,>=3.1.0 in c:\users\oormi\anaconda3\lib\site-packages (from geoviews) (3.2.2)
# Requirement already satisfied: param in c:\users\oormi\anaconda3\lib\site-packages (from geoviews) (1.12.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\oormi\anaconda3\lib\site-packages (from geoviews) (1.17.1)
# Requirement already satisfied: numpy in c:\users\oormi\anaconda3\lib\site-packages (from geoviews) (1.21.5)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\oormi\anaconda3\lib\site-packages (from geoviews) (0.22.0)
# Requirement already satisfied: packaging in c:\users\oormi\anaconda3\lib\site-packages (from geoviews) (21.3)
# Requirement already satisfied: panel>=1.0.0 in c:\users\oormi\anaconda3\lib\site-packages (from geoviews) (1.2.3)
# Requirement already satisfied: pyproj in c:\users\oormi\anaconda3\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in c:\users\oormi\anaconda3\lib\site-packages (from geoviews) (2023.10.0)
# Requirement already satisfied: shapely in c:\users\oormi\anaconda3\lib\site-packages (from geoviews) (2.0.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\oormi\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\oormi\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (9.0.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\oormi\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\oormi\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.4.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\oormi\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (2.11.3)
# Requirement already satisfied: contourpy>=1 in c:\users\oormi\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.1.1)
# Requirement already satisfied: pyshp>=2.1 in c:\users\oormi\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\oormi\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.5.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\oormi\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (2.0.2)
# Requirement already satisfied: colorcet in c:\users\oormi\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (2.0.6)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\oormi\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.3.0,>=3.1.0->geoviews) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\oormi\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\oormi\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\oormi\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\oormi\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\oormi\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\oormi\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.3.0,>=3.1.0->geoviews) (2021.3)
# Requirement already satisfied: markdown in c:\users\oormi\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.3.4)
# Requirement already satisfied: mdit-py-plugins in c:\users\oormi\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.4.0)
# Requirement already satisfied: markdown-it-py in c:\users\oormi\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.0.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\oormi\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.64.0)
# Requirement already satisfied: typing-extensions in c:\users\oormi\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.1)
# Requirement already satisfied: bleach in c:\users\oormi\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: linkify-it-py in c:\users\oormi\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.2)
# Requirement already satisfied: requests in c:\users\oormi\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.27.1)
# Requirement already satisfied: certifi in c:\users\oormi\anaconda3\lib\site-packages (from pyproj->geoviews) (2021.10.8)
# Requirement already satisfied: six>=1.5 in c:\users\oormi\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.16.0)
# Requirement already satisfied: colorama in c:\users\oormi\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\oormi\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\oormi\anaconda3\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.4.6)
# Requirement already satisfied: uc-micro-py in c:\users\oormi\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\oormi\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\oormi\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\oormi\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\oormi\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 400,
    frame_height = 300,
    size = "Humidity",
    color = "City",
    scale = 0.5
)
    

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_df = city_data_df.loc[(city_data_df["Max Temp"] >= 21) &
                            (city_data_df["Max Temp"] <= 30) &
                            (city_data_df["Cloudiness"] == 0)]

# Drop any rows with null values
ideal_df.dropna(how='all')

# Display sample data
ideal_df.head()
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 39        39               al wakrah  24.8500   51.3333     26.05        45
# 48        48  hawaiian paradise park  19.5933 -154.9731     25.73        86
# 176      176                 awjilah  29.1081   21.2869     22.16        29
# 231      231                 urangan -25.3000  152.9000     23.37        72
# 255      255                   rundu -17.9333   19.7667     23.96        12
#
#      Cloudiness  Wind Speed Country        Date
# 39            0        2.06      QA  1698036281
# 48            0        3.60      US  1698036287
# 176           0        2.12      LY  1698036361
# 231           0        7.90      AU  1698036392
# 255           0        3.60     NaN  1698036405

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = pd.DataFrame({"City": ideal_df["City"],
                         "Country": ideal_df["Country"],
                         "Lat": ideal_df["Lat"],
                         "Lng": ideal_df["Lng"],
                         "Humidity": ideal_df["Humidity"]})

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#                        City Country      Lat       Lng  Humidity Hotel Name
# 39                al wakrah      QA  24.8500   51.3333        45
# 48   hawaiian paradise park      US  19.5933 -154.9731        86
# 176                 awjilah      LY  29.1081   21.2869        29
# 231                 urangan      AU -25.3000  152.9000        72
# 255                   rundu     NaN -17.9333   19.7667        12

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "limit": 20,
    "apiKey": geoapify_key,
    "categories": "accommodation.hotel"
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = hotel_df.loc[index, "Lng"]
    latitude = hotel_df.loc[index, "Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# al wakrah - nearest hotel: No hotel found
# hawaiian paradise park - nearest hotel: No hotel found
# awjilah - nearest hotel: No hotel found
# urangan - nearest hotel: Ramada
# rundu - nearest hotel: Kavango River Lodge
# sanford - nearest hotel: Park Place Inn, Cottages, & Catering
# les avirons - nearest hotel: Floralys
# saint-pierre - nearest hotel: Tropic Hotel
# forster - nearest hotel: No hotel found
# waddan - nearest hotel: No hotel found
# broken hill - nearest hotel: Ibis Styles
# zouerate - nearest hotel: فندق تيرس زمور
# kingman - nearest hotel: Home2 Suites by Hilton Kingman
# al wasitah - nearest hotel: No hotel found
# douz - nearest hotel: Louage station Douz
# nouadhibou - nearest hotel: Hotel valencia
# ad dilam - nearest hotel: No hotel found
# gebeit - nearest hotel: No hotel found
# santarem - nearest hotel: Prático Hotel
# qianjiang - nearest hotel: No hotel found
# arkansas city - nearest hotel: Best Western Atrium Gardens
#                        City Country      Lat       Lng  Humidity  \
# 39                al wakrah      QA  24.8500   51.3333        45
# 48   hawaiian paradise park      US  19.5933 -154.9731        86
# 176                 awjilah      LY  29.1081   21.2869        29
# 231                 urangan      AU -25.3000  152.9000        72
# 255                   rundu     NaN -17.9333   19.7667        12
# 270                 sanford      US  28.8006  -81.2731        83
# 301             les avirons      RE -21.2418   55.3394        57
# 307            saint-pierre      RE -21.3393   55.4781        57
# 314                 forster      AU -32.1667  152.5167        52
# 342                  waddan      LY  29.1614   16.1390        46
# 352             broken hill      AU -31.9500  141.4333        17
# 375                zouerate      MR  22.7187  -12.4521        77
# 410                 kingman      US  35.1894 -114.0530        17
# 417              al wasitah      EG  29.3378   31.2056        86
# 421                    douz      TN  33.4663    9.0203        36
# 505              nouadhibou      MR  20.9310  -17.0347        88
# 506                ad dilam      SA  23.9915   47.1627        38
# 538                  gebeit      SD  21.0667   36.3167        53
# 546                santarem      BR  -2.4431  -54.7083        89
# 551               qianjiang      CN  30.4151  112.8859        29
# 574           arkansas city      US  37.0620  -97.0384        64
#
#                                Hotel Name
# 39                         No hotel found
# 48                         No hotel found
# 176                        No hotel found
# 231                                Ramada
# 255                   Kavango River Lodge
# 270  Park Place Inn, Cottages, & Catering
# 301                              Floralys
# 307                          Tropic Hotel
# 314                        No hotel found
# 342                        No hotel found
# 352                           Ibis Styles
# 375                        فندق تيرس زمور
# 410        Home2 Suites by Hilton Kingman
# 417                        No hotel found
# 421                   Louage station Douz
# 505                        Hotel valencia
# 506                        No hotel found
# 538                        No hotel found
# 546                         Prático Hotel
# 551                        No hotel found
# 574           Best Western Atrium Gardens

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 400,
    frame_height = 300,
    size = "Humidity",
    color = "City",
    scale = 0.5,
    hover_cols='all',
    use_index=False
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
